# %% [markdown]
# ## **Install package**

# %%
# !pip install --quiet langchain
# !pip install --quiet langchain-openai
# !pip install --quiet langchain-core
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 990.6/990.6 kB 19.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.0/384.0 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.2/140.2 kB 9.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 360.7/360.7 kB 19.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 11.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 20.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.1 MB/s eta 0:00:00

# %% [markdown]
# ## **Setting**

# %%
from getpass import getpass
import os

OPENAI_API_KEY = getpass()
ORGANIZATION_ID = getpass()
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY
os.environ["OPENAI_ORGANIZATION"] = ORGANIZATION_ID
# Out:
# ··········
# ··········

# %%
print (OPENAI_API_KEY)
print (ORGANIZATION_ID)
# Out:
# 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
# org-EkieKrMNeYQoV4o2eJCWUhJa

# %% [markdown]
# ## **開始程式**

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="gpt-4o",
    temperature=0,
    max_tokens=500,
    timeout=None,
    max_retries=2,
    # api_key="...",  # if you prefer to pass api key in directly instaed of using env vars
    # base_url="...",
    # organization="...",
    # other params...
)

# %%
import requests

# Google Doc 的公開網址
doc_url = 'https://docs.google.com/document/d/1IJN624UTsWLh7Q43CLLvRNY4mN--8Cfd--oWXKwWfUE/export?format=txt'

# 發送 GET 請求以讀取 Google Doc 的內容
response = requests.get(doc_url)
document_text = response.text

#print (document_text)
print ("成功取得，token數=",len(document_text) )
# Out:
# 成功取得，token數= 7792

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.prompts import PromptTemplate

chat_template = ChatPromptTemplate.from_messages(
 [
    ("system","你是一個旅遊行程助理，請使用繁體中文回覆."),
    ("human", document_text),
    ('human', '{param_ques}'),
 ]
)

messages = chat_template.format_messages(param_ques='第一天的飛機是哪時候?')
messages

ai_msg = llm.invoke(messages)
#ai_msg #可以看到詳細訊息
print(ai_msg.content)
# Out:
# 第一天的飛機資訊如下：
#
# - **筑家**：10:40 -> 15:00 / JX802
# - **寶家**：10:40 -> 15:00 / JX802
#
# 請注意，這是從桃園機場出發，抵達東京的航班時間。

# %%
messages = chat_template.format_messages(param_ques='最後一天的飛機是哪時候?')
print (llm.invoke(messages).content)
# Out:
# 最後一天的飛機時間是7月20日，筑家和寶家的航班都是16:10從東京出發，預計18:50抵達。航班號是JX803。

# %%
messages = chat_template.format_messages(param_ques='有安排吃厥餅嗎?')
print (llm.invoke(messages).content)
# Out:
# 是的，有安排吃厥餅。根據行程表，7月12日晚上在淺草東武飯店附近的淺草吉貝糰子可以品嚐到厥餅。這家店的營業時間是11:00到18:00，建議在這段時間內前往品嚐。
#
# 以下是相關資訊：
# - **淺草吉貝糰子**
#   - 地址: [地圖連結](https://maps.app.goo.gl/WrRF8WN8u2JUiFBf6?g_st=com.google.maps.preview.copy)
#   - 營業時間: 11:00 - 18:00
#   - 特色: 據說是江戶時代流傳下來的街頭小吃，吃起來像是厥餅。外層裹上厚厚的一層黃豆粉，搭配無糖抹茶享用，不甜不膩。
#
# 希望這個資訊對你有幫助，祝你旅途愉快！

# %%
messages = chat_template.format_messages(param_ques='筑幫我代付多少錢? 我給他錢了沒?')
print (llm.invoke(messages).content)
# Out:
# 根據你提供的資訊，筑幫你代付的費用如下：
#
# 1. 7/12-14 淺草東武飯店 三人房二間 每家TWD 10,133/二晚
# 2. 7/16-17 鬼怒川阿寶家房費 TWD 11,235
# 3. 7/20 機場接送 TWD 3,508
# 4. 7/14-17 日光週遊券 TWD 2,464（二大二小）
#
# 總計：TWD 27,340
#
# 根據你提供的資訊，7/6 小計 TWD 27,340，並且在 7/8 阿寶已轉帳。因此，你已經給筑錢了。

# %%
messages = chat_template.format_messages(param_ques='我們哪一天要去日光?')
print (llm.invoke(messages).content)
# Out:
# 根據行程表，你們將在7月14日從東京前往日光，並在日光進行四天三夜的小旅行。具體行程如下：
#
# - **7月14日**：從東京的東武淺草站搭乘特急列車前往東武日光站，並入住Nikko Station Hotel Classic。
# - **7月15日**：在日光旅遊，參觀中禪寺湖、華嚴瀑布、明智平纜車等景點。
# - **7月16日**：從日光前往鬼怒川，入住鬼怒川溫泉飯店。
# - **7月17日**：早上退房後，搭乘列車返回東京。
#
# 希望這些資訊對你有幫助，祝你們旅途愉快！

# %%
messages = chat_template.format_messages(param_ques='我兒子最愛的奧特曼行程有安排嗎? 哪一天?')
print (llm.invoke(messages).content)
# Out:
# 根據您的行程安排，奧特曼商店街的行程安排在7月19日。以下是詳細資訊：
#
# ### 7月19日
# - **自由活動**
# - **寶家: 奧特曼商店街**
#   - 地址: [奧特曼商店街](https://reurl.cc/OMZNQr)
#
# 您可以在這一天帶您的兒子前往奧特曼商店街，讓他盡情享受他最愛的奧特曼相關活動和商品。希望這個行程能讓您的兒子度過一個愉快的時光！

# %%
messages = chat_template.format_messages(param_ques='有吃燒肉嗎?')
print (llm.invoke(messages).content)
# Out:
# 是的，行程中有安排吃燒肉的部分。以下是相關資訊：
#
# ### 7月18日
# **午餐: 游玄亭 有樂町Mullion店**
# - 地址: https://maps.app.goo.gl/FmPu8qrwzWzQ2a2g6?g_st=com.google.maps.preview.copy
# - 訂位時間: 12:00
#   - 筑家: 3位 Fan Pei-Chu
#   - 寶家: 4位 Yang Wan-Ching
#
# ### 其他推薦燒肉店
# **房家 一頭牛燒肉 上野**
# - 地址: https://maps.app.goo.gl/f5xef9FBdVkik2Kq9?g_st=com.google.maps.preview.copy
#
# **房家日本橋店**
# - 地址: https://maps.app.goo.gl/Xq2Ybats2fWBaDGi9?g_st=com.google.maps.preview.copy
#
# 這些燒肉店都是非常受歡迎的選擇，建議提前預訂以確保有座位。希望你們能享受美味的燒肉！

# %%
messages = chat_template.format_messages(param_ques='裡面有安排迴轉壽司嗎?')
print (llm.invoke(messages).content)
# Out:
# 目前行程表中沒有特別安排迴轉壽司的用餐。不過，如果您有興趣，我可以推薦幾家東京知名的迴轉壽司店，並幫您安排在合適的時間前往。
#
# ### 推薦的迴轉壽司店：
# 1. **壽司大（Sushi Dai）**
#    - 地址：東京都中央區築地5-2-1 築地市場6號館
#    - 營業時間：5:00 - 14:00
#    - 備註：築地市場內的壽司店，早上去排隊比較好。
#
# 2. **壽司三昧（Sushizanmai）**
#    - 地址：東京都中央區築地4-11-9
#    - 營業時間：24小時
#    - 備註：築地市場附近，24小時營業，非常方便。
#
# 3. **壽司郎（Sushiro）**
#    - 地址：東京都多個分店
#    - 營業時間：各分店不同，通常10:00 - 23:00
#    - 備註：連鎖迴轉壽司店，價格實惠，品質穩定。
#
# ### 安排建議：
# 您可以在自由活動的時間或是某天的午餐/晚餐時間前往這些迴轉壽司店。例如：
#
# - **7月13日**：在淺草東武飯店附近活動，午餐或晚餐可以安排去壽司三昧。
# - **7月19日**：自由活動日，可以安排前往築地市場，享受壽司大或壽司三昧。
#
# 請告訴我您的偏好和時間安排，我可以幫您更詳細地規劃。

# %%
messages = chat_template.format_messages(param_ques='這一次有搭火車嗎?')
print (llm.invoke(messages).content)
# Out:
# 是的，這次行程中有多次搭乘火車的安排。以下是具體的火車行程：
#
# 1. **7月12日**：
#    - 從成田機場或羽田機場到淺草東武飯店：
#      - Skyliner（京成上野方向）到上野，然後轉地鐵銀座線
#      - 或Skyaccess私鐵（羽田方向）到淺草
#
# 2. **7月14日**：
#    - 從東武淺草站到東武日光站：
#      - 搭乘特急列車（特急けごん號），約1小時50分鐘
#
# 3. **7月17日**：
#    - 從鬼怒川溫泉站到下今市站：
#      - 一般列車：10:48 鬼怒川溫泉 -> 11:14 下今市
#      - Revaty Kinu No.124（前往淺草）：11:10 鬼怒川溫泉 -> 11:29 下今市
#    - 從下今市站到淺草站：
#      - SPACIA x 4 cockpit car 1號包廂：12:02 下今市 -> 13:45 淺草
#
# 這些火車行程將帶您從東京到日光和鬼怒川，並在返回東京後入住文華東方酒店。希望這些資訊對您有幫助，祝您旅途愉快！

# %%
messages = chat_template.format_messages(param_ques='寶一家人成員及護照號碼裡面有嗎? 我需要幫忙訂房。')
print (llm.invoke(messages).content)
# Out:
# 寶一家成員及護照號碼如下：
#
# 1. 張秉聖 Chang Ping Sheng  38232323
# 2. 楊宛青 YANG WAN CHING 49323234
# 3. 張欣瑜 CHANG SHIN YU   04041122
# 4. 張晉杰 CHANG JIN JIE  23232323
#
# 請問還有其他需要協助的事項嗎？例如訂房的具體需求或其他行程安排？
